# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### import data

# %%
df=pd.read_csv("laptop_prices_dataset.csv")

# %%
df.head(3)
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
#
#   PrimaryStorage  SecondaryStorage PrimaryStorageType  SecondaryStorageType  \
# 0            128                 0                SSD                    No
# 1            128                 0      Flash Storage                    No
# 2            256                 0                SSD                    No
#
#    GPU_company               GPU_model
# ...

# %%
df.columns.values
# Out:
# array(['Company', 'Product', 'TypeName', 'Inches', 'Ram', 'OS', 'Weight',
#        'Price_euros', 'Screen', 'ScreenW', 'ScreenH', 'Touchscreen',
#        'IPSpanel', 'RetinaDisplay', 'CPU_company', 'CPU_freq',
#        'CPU_model', 'PrimaryStorage', 'SecondaryStorage',
#        'PrimaryStorageType', 'SecondaryStorageType', 'GPU_company',
#        'GPU_model'], dtype=object)

# %%
df.shape
# Out:
# (1275, 23)

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1275 non-null   object
#  3   Inches                1275 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           1275 non-null   object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %%
df['OS'].unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', 'Linux', 'Android',
#        'Windows 10 S', 'Chrome OS', 'Windows 7'], dtype=object)

# %%
df['OS'].nunique()
# Out:
# 9

# %%
#df.drop(columns=['Unnamed:0'],inplace=True)
#df["Ram"]=df["Ram"].str.replace("GB","")
#df["Weight"]=df["Weight"].str.replace("kg","")
#df["Ram"]=df["Ram"].astype("int")
#df["Weight"]=df["Weight"].astype("float")

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#             Inches          Ram       Weight  Price_euros      ScreenW  \
# count  1275.000000  1275.000000  1275.000000  1275.000000  1275.000000
# mean     15.022902     8.440784     2.040525  1134.969059  1900.043922
# std       1.429470     5.097809     0.669196   700.752504   493.346186
# min      10.100000     2.000000     0.690000   174.000000  1366.000000
# 25%      14.000000     4.000000     1.500000   609.000000  1920.000000
# 50%      15.600000     8.000000     2.040000   989.000000  1920.000000
# 75%      15.600000     8.000000     2.310000  1496.500000  1920.000000
# max      18.400000    64.000000     4.700000  6099.000000  3840.000000
#
#            ScreenH     CPU_freq  PrimaryStorage  SecondaryStorage
# count  1275.000000  1275.000000     1275.000000       1275.000000
# mean   1073.904314     2.302980      444.517647        176.069020
# std     283.883940     0.503846      365.537726        415.960655
# ...

# %% [markdown]
# # Data is neat and clean and its ready to EDA & visualization then find the insight inLaptop sales analysis dataset

# %% [markdown]
# ### Exploratory data analysis by: Univeriate analysis and feature engineering

# %% [markdown]
# #column by prices_euros

# %%
# Create a distribution plot using histplot
y = sns.histplot(df["Price_euros"], kde=True)  # kde=True adds a kernel density estimate
plt.title('Distribution of Price in Euros')
plt.xlabel('Price (Euros)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# #The analysis reveals the distribution of prices in euros, highlighting key trends and patterns. This visualization aids in understanding the price range and density, providing valuable insights for decision-making

# %% [markdown]
# ## Column -> company

# %%
df["Company"].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df["Company"].value_counts().sum()
# Out:
# 1275

# %% [markdown]
# #total number of laptop is 1275 in all company

# %%
plt.figure(figsize=(12,5))
plt.title('Total Number Count by Company')
y=df['Company'].value_counts().plot(kind='bar')
for bar in y.containers:
    y.bar_label(bar)
plt.xlabel('Company')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Dell, Lenovo, and HP dominate the market, with each having close to 300 units, significantly ahead of other brands.
# ### Asus and Acer hold mid-tier positions, with 152 and 101 units respectively, showing a notable presence.
# ### Brands like Apple, Samsung, and Microsoft have relatively low counts, while Huawei has the least representation with just 2 units.

# %% [markdown]
# # Column OS

# %%
df['OS'].value_counts()
# Out:
# OS
# Windows 10      1048
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 5))
plt.title('Total number count by OS')

# Get the value counts of the 'OS' column
os_counts = df['OS'].value_counts()

# Plot the bar chart
bars = os_counts.plot(kind='bar')

# Add labels to the bars
for bar in bars.containers:
    bars.bar_label(bar)

plt.xlabel('OS')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Windows 10 is the dominant OS with 1048 users, vastly outpacing all other operating systems.
# ## Linux and "No OS" options have moderate adoption, with 58 and 66 users respectively, suggesting some preference for open-source or customizable setups.
# ## macOS, Windows 10 S, and Android have very low usage, indicating limited adoption in this dataset.

# %% [markdown]
# # Column Touchscreen

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# No     1087
# Yes     188
# Name: count, dtype: int64

# %%
df['Touchscreen'].value_counts().plot(kind='pie', autopct='%.2f%%' ,title='Touchscreen')
# Out:
# <Axes: title={'center': 'Touchscreen'}, ylabel='count'>

# %% [markdown]
# ### ouchscreen laptops are a minority, making up only 14.75% of the total.
# ### The vast majority (85.25%) of laptops do not have touchscreen functionality, indicating traditional screens remain dominant.
# ### Touchscreen adoption is relatively low, possibly due to cost, battery concerns, or user preference for non-touch displays.

# %% [markdown]
# # Column-> RAM

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     613
# 4     367
# 16    198
# 6      35
# 12     25
# 32     17
# 2      16
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
y=df['Ram'].value_counts().plot(kind='bar')
for bar in y.containers:
    y.bar_label(bar)
plt.title("Total Number Count of Ram")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 8GB RAM is the most common configuration, with 613 laptops featuring it, followed by 4GB (367) and 16GB (198).
# ### Lower RAM options like 2GB and 6GB are significantly less common, indicating a shift toward higher memory capacities.
# ### High-end configurations like 32GB and 64GB are rare, suggesting they are mostly found in premium or specialized device

# %% [markdown]
# # Columns GPU_company

# %%
df['GPU_company'].value_counts()
# Out:
# GPU_company
# Intel     704
# Nvidia    396
# AMD       174
# ARM         1
# Name: count, dtype: int64

# %%
df['GPU_company'].value_counts().plot(kind='pie', autopct='%.2f%%' ,title='GPU_company')
# Out:
# <Axes: title={'center': 'GPU_company'}, ylabel='count'>

# %% [markdown]
# ### Intel dominates the GPU market with 55.22% share, followed by Nvidia at 31.06%.
# ### AMD holds a smaller but notable share of 13.65%, making it the third most common GPU provider.
# ### ARM has an extremely minimal presence (0.08%), indicating its limited use in this dataset.

# %%
plt.figure(figsize=(5,4))
g=df['GPU_company'].value_counts().plot(kind='bar') 
for bar in g.containers:
    g.bar_label(bar)

plt.ylabel("count")
plt.xlabel("GPU_company")
plt.xticks(rotation=49)
plt.show()

# %% [markdown]
# ### Intel leads the GPU market with 704 units, followed by Nvidia (396) and AMD (174).
# ### Nvidia holds a strong second position, indicating its significant presence in the discrete GPU segment.
# ### ARM has a negligible share with just one unit, suggesting minimal representation in this dataset

# %% [markdown]
# # Column -> CPU_company

# %%
df['CPU_company'].value_counts()
# Out:
# CPU_company
# Intel      1214
# AMD          60
# Samsung       1
# Name: count, dtype: int64

# %%
df['CPU_company'].value_counts().plot(kind='pie',autopct='%.2f%%' ,title='CPU_company')
# Out:
# <Axes: title={'center': 'CPU_company'}, ylabel='count'>

# %% [markdown]
# ### Intel dominates the market with 95.22% share, making it the overwhelmingly preferred processor brand.
# ### AMD (4.71%) and Samsung (0.08%) have minimal presence, indicating limited competition in this dataset.

# %% [markdown]
# # Column IPSpanel

# %%
df['IPSpanel'].value_counts()
# Out:
# IPSpanel
# No     918
# Yes    357
# Name: count, dtype: int64

# %%
df['IPSpanel'].value_counts().plot(kind='pie',autopct='%.2f%%' ,title='IPSpanel')
# Out:
# <Axes: title={'center': 'IPSpanel'}, ylabel='count'>

# %% [markdown]
# ### 72% of the products do not have a touchscreen, indicating a preference for non-touch models.
# ### Only 28% have a touchscreen, suggesting that touch functionality is a less common feature in this dataset.

# %% [markdown]
# # Column Inches

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    647
# 14.0    193
# 17.3    164
# 13.3    160
# 12.5     39
# 11.6     31
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: count, dtype: int64

# %%
#a=sns.countplot(x='Inches',data=df)
#for bar in a.containers:
   # a.bar_label(bar )

# %%
# Plot the value counts of the 'Inches' column
a = df['Inches'].value_counts().plot(kind='bar')

# Add labels to each bar
for container in a.containers:
    a.bar_label(container)
plt.ylabel("count")
plt.xlabel("Inches")
plt.xticks(rotation=49)


# Show the plot
plt.show()

# %% [markdown]
# ### The 15.6-inch screen size is the most common, with 647 units, indicating it as the preferred choice for most users.
# ### 14.0-inch and 17.3-inch screens follow, with 193 and 164 units, respectively, showing moderate popularity.
# ### Smaller and larger screen sizes (below 12 inches and above 17 inches) are rare, suggesting they cater to niche markets.

# %% [markdown]
# # Column PrimaryStorageType

# %%
y=df['PrimaryStorageType'].value_counts()
y
# Out:
# PrimaryStorageType
# SSD              837
# HDD              359
# Flash Storage     71
# Hybrid             8
# Name: count, dtype: int64

# %%
y=df['PrimaryStorageType'].value_counts().plot(kind = 'pie' ,
autopct = '%.2f%%', title='Percent of PrimaryStorageType')

# %% [markdown]
# ### SSD is the dominant primary storage type (65.65%), followed by HDD (28.16%), indicating a preference for faster storage solutions.
# ### Hybrid (0.63%) and Flash Storage (5.57%) have minimal market share, suggesting they are niche choices compared to SSD and HDD.

# %% [markdown]
# # Column Screen

# %%
x=df['Screen'].value_counts()
x
# Out:
# Screen
# Full HD        835
# Standard       369
# 4K Ultra HD     43
# Quad HD+        28
# Name: count, dtype: int64

# %%
x=df['Screen'].value_counts().plot(kind='bar')
plt.title('Total_screen ')
plt.figure(figsize=(12,4))
for bars in x.containers:
    x.bar_label(bars)
plt.show()

# %% [markdown]
# ### Full HD screens dominate the market (835 units), significantly outnumbering other screen types, indicating a strong preference for this resolution.
# ### Higher-resolution screens like 4K Ultra HD (43) and Quad HD+ (28) have much lower adoption, suggesting they are premium or niche choices.

# %% [markdown]
# # Column SecondarystorageType

# %%
t=df['SecondaryStorageType'].value_counts().plot(kind='bar',title='Count of secondary storage type')
for bar in t.containers:
    t.bar_label(bar)
plt.ylabel("Count")
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# ### The majority of devices (1067) do not have secondary storage, indicating a preference for single-storage configurations.
# ### HDD is the most common secondary storage option (202 units), while SSD (4) and Hybrid (2) are rarely used.

# %% [markdown]
# # Product  column

# %%
t=df['Product'].value_counts().plot(kind='line',title='Count of product')
for bar in t.containers:
    t.line_label(line)
plt.ylabel("Count")
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# ### he XPS 13 is the most common laptop model, with significantly higher availability compared to other models.
# ### The distribution follows a steep drop-off, indicating that only a few models dominate the market while many others have low availability.
# ### Laptops such as Latitude 7280 and Tecra A50-D-11D are relatively more common, but many models appear only a few times in the dataset.

# %% [markdown]
# # -> Subplot of 'Ram', 'OS', 'Touchscreen', 'IPSpanel', 'RetinaDisplay', 'CPU_company

# %%
# Define the categorical columns to plot
columns_to_plot = ['Ram', 'OS', 'Touchscreen', 'IPSpanel', 'RetinaDisplay', 'CPU_company']

# Set up subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))  # Adjust rows and columns as needed
axes = axes.flatten()  # Flatten for easy iteration

# Create countplots for each categorical column
for i, col in enumerate(columns_to_plot):
    sns.countplot(x=df[col], ax=axes[i], palette="Set2")
    axes[i].set_title(f"Count of {col}")
    axes[i].set_ylabel("Count")
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The most common RAM size is 8GB, followed by 4GB and 16GB, while higher capacities like 32GB and 64GB are rare.
# ### Windows 10 dominates the OS category, with very few devices running other operating systems.
# ### Touchscreen laptops are significantly fewer, making up a small portion of the total.
# ### Intel CPUs are overwhelmingly dominant, with AMD and Samsung having a minimal presence.
# ### Most devices lack IPS panels and Retina displays, indicating a preference for standard screen technology.

# %% [markdown]
# ### Biveriate analysis

# %% [markdown]
# # Column  OS and Pricea_euros

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.set(style='darkgrid')
sns.scatterplot(x=df['OS'],y=df['Price_euros'])
plt.Title=('OS vs price_frequency')
plt.show()

# %% [markdown]
# # The scatter plot visualizes laptop prices (in euros) based on different operating systems, showing a wide range of price variations. Windows 10 and macOS have the highest price outliers, while Linux and Android tend to be on the lower end.

# %% [markdown]
# ## OS vs price_euros

# %%
# Set the style and size of the plot
sns.set(style='darkgrid')
sns.set(rc={'figure.figsize':(15, 5)})

# Create the bar plot
bar_plot = sns.barplot(x=df['OS'], y=df['Price_euros'], palette='Blues')

 # Add labels and title
bar_plot.set_title('Price of Laptops by Operating System', fontsize=16)
bar_plot.set_xlabel('Operating System', fontsize=14)
bar_plot.set_ylabel('Price (Euros)', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# ### Here are some insights from the bar plot:
#
# ### macOS and Windows 7 have the highest average laptop prices, suggesting that premium laptops are often associated with these operating systems.
# ### Windows 10 and Mac OS X also have relatively high prices, indicating their presence in mid-to-high-range laptop categories.
# ### No OS, Linux, and Android laptops tend to be more affordable, likely because they are budget-friendly or targeted at specific user groups.
# ### Windows 10 S shows a wide price variation, implying that it is available in both budget and premium laptops.
# ### Chrome OS is on the lower end, reflecting its dominance in budget-friendly Chromebook models.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1275 non-null   object
#  3   Inches                1275 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           1275 non-null   object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
# ...

# %% [markdown]
# # Column Touchscreen and prices_euros

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x=df['Touchscreen'],y=df['Price_euros'],hue=df['Screen'])
plt.title("Touchscreen vs price_euros with hue schreen",fontsize=20)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Here are some key insights from the bar plot:
#
# #### Higher screen resolutions correlate with higher prices – Laptops with 4K Ultra HD and Quad HD+ displays are significantly more expensive than those with Standard or Full HD screens.
# #### Touchscreen laptops (Yes) are generally more expensive than non-touchscreen (No) models across all screen resolutions.
# #### The price difference between touch and non-touch laptops is more noticeable for higher resolutions – 4K Ultra HD and Quad HD+ touchscreens show a slight price increase compared to their non-touch counterparts.
# #### Standard resolution laptops remain the most affordable option, regardless of touchscreen availability.
# #### Error bars suggest price variations within each category, especially for higher resolutions like 4K Ultra HD, where premium models contribute to the wider price range.

# %% [markdown]
# # Column screen and prices_euros

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x=df['Screen'],y=df['Price_euros'],hue=df['Touchscreen'])
plt.title("Screen vs price_euros with hue Touchschreen",fontsize=20)

plt.show()

# %% [markdown]
# ###### here are some insights from the bar plot:
#
# ##### Touchscreen laptops tend to be more expensive for lower resolutions – Standard and Quad HD+ screens show a noticeable price increase for touchscreen models.
# ##### For Full HD and 4K Ultra HD, the price difference between touchscreen and non-touchscreen laptops is minimal, suggesting that touchscreen capability is less of a price determinant in premium models.
# ##### 4K Ultra HD laptops are the most expensive, with both touchscreen and non-touchscreen variants having the highest average prices.
# ##### Standard resolution laptops show the greatest price gap between touchscreen and non-touchscreen models, indicating that touchscreen functionality significantly impacts pricing in budget categori

# %% [markdown]
# # Column OS and prices_euros

# %%
plt.Figure(figsize=(10,4))
sns.barplot(x=df['OS'],y=df['Price_euros'],hue=df['Touchscreen'])

plt.show()

# %% [markdown]
# ### macOS and Windows 7 have the highest average prices, with touchscreen models slightly more expensive than non-touch models.
# ### Windows 10 S and Linux touchscreen laptops show a significant price increase, indicating premium models in these categories.
# ### Chrome OS and Android remain the most budget-friendly options, with minimal price differences between touchscreen and non-touchscreen models.

# %% [markdown]
# # Column Primarystorage and prices_euros

# %%
plt.Figure(figsize=(10,4))
sns.barplot(x=df['PrimaryStorage'],y=df['Price_euros'],hue=df['SecondaryStorage'])

plt.show()

# %% [markdown]
# ### Laptops with higher primary storage (1024GB & 2048GB) generally have higher prices, especially when paired with additional secondary storage.
# ### Devices with no secondary storage tend to be more affordable, except in cases where high primary storage compensates for it.
# ### Significant price variations exist within the same primary storage category, indicating the influence of other premium features beyond just storage capacity

# %% [markdown]
# # Column retinaDisplay and prices_euros

# %%
#sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=df,x=df['RetinaDisplay'],y=df['Price_euros'],hue=df['PrimaryStorage'])
plt.show()

# %% [markdown]
# ### Laptops with Retina Display tend to have higher prices compared to those without, especially in higher storage variants.
#
# ### Price variation is more significant in non-Retina laptops, with a wider range of price points across different storage capacities.
#
# ### Higher storage capacities (e.g., 2000 GB) generally correlate with increased prices, but the effect is more prominent in non-Retina models.
#
# ### The price difference between Retina and non-Retina models is more noticeable at lower storage levels but evens out at higher storage capacities.

# %%
sns.scatterplot(data = df , x= df['CPU_freq'], y =
df['Ram'], hue = df['OS'])
# Out:
# <Axes: xlabel='CPU_freq', ylabel='Ram'>

# %% [markdown]
# ### Most laptops have CPU frequencies between 1.0 GHz and 3.0 GHz, with RAM capacities varying significantly within this range.
# ### igher RAM values (above 20GB) are found in laptops with CPU frequencies above 2.5 GHz, indicating high-performance machines.
# ### Windows 10 dominates the dataset, while Chrome OS and macOS appear in specific clusters, likely representing budget and premium devices, respectively.
